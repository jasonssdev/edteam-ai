# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Path
current_path = os.getcwd()
base_path = os.path.abspath(os.path.join(current_path, '..'))
raw_data_path = os.path.join(base_path, 'data', 'raw')
processed_data_path = os.path.join(base_path, 'data', 'processed')
wc_raw_data_path = os.path.join(raw_data_path, 'worldcup_raw_data.csv')
results_raw_data_path = os.path.join(raw_data_path, 'results.csv')

# %%
wc_df = pd.read_csv(wc_raw_data_path, sep=',')

# %%
wc_df.head()
# Out:
#            Team Group  Previous \nappearances  Previous \ntitles  \
# 0        Russia     A                    10.0                0.0
# 1  Saudi Arabia     A                     4.0                0.0
# 2         Egypt     A                     2.0                0.0
# 3       Uruguay     A                    12.0                2.0
# 4       Porugal     B                     6.0                0.0
#
#    Previous\n finals  Previous\n semifinals  Current \nFIFA rank  \
# 0                0.0                    1.0                 65.0
# 1                0.0                    0.0                 63.0
# 2                0.0                    0.0                 31.0
# 3                2.0                    5.0                 21.0
# 4                0.0                    2.0                  3.0
#
#   First match \nagainst  Match index  history with \nfirst opponent\n W-L  \
# 0          Saudi Arabia          1.0                                 -1.0
# ...

# %%
wc_df.describe()
# Out:
#        Previous \nappearances  Previous \ntitles  Previous\n finals  \
# count               32.000000          32.000000          32.000000
# mean                 7.906250           0.500000           0.843750
# std                  5.426098           1.191367           2.017814
# min                  0.000000           0.000000           0.000000
# 25%                  4.000000           0.000000           0.000000
# 50%                  5.500000           0.000000           0.000000
# 75%                 12.000000           0.000000           0.250000
# max                 20.000000           5.000000           8.000000
#
#        Previous\n semifinals  Current \nFIFA rank  Match index  \
# count              32.000000            32.000000    32.000000
# mean                1.781250            24.781250     8.500000
# std                 3.128788            19.536128     4.683533
# min                 0.000000             1.000000     1.000000
# ...

# %%
wc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 20 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Team                                  32 non-null     object
#  1   Group                                 32 non-null     object
#  2   Previous
# appearances                 32 non-null     float64
#  3   Previous
# titles                      32 non-null     float64
#  4   Previous
#  finals                      32 non-null     float64
#  5   Previous
#  semifinals                  32 non-null     float64
#  6   Current
# FIFA rank                    32 non-null     float64
#  7   First match
# against                  32 non-null     object
#  8   Match index                           32 non-null     float64
#  9   history with
# first opponent
#  W-L     20 non-null     float64
#  10  history with
#  first opponent
# ...

# %%
wc_df.ndim
# Out:
# 2

# %%
wc_df.size
# Out:
# 660

# %%
wc_df.shape
# Out:
# (33, 20)

# %%
result_df = pd.read_csv(results_raw_data_path, sep=',')

# %%
result_df.head(3)
# Out:
#    year        date home_team away_team  home_score  away_score tournament  \
# 0  1872  1872-11-30  Scotland   England           0           0   Friendly
# 1  1873  1873-03-08   England  Scotland           4           2   Friendly
# 2  1874  1874-03-07  Scotland   England           2           1   Friendly
#
#       city   country  neutral
# 0  Glasgow  Scotland    False
# 1   London   England    False
# 2  Glasgow  Scotland    False

# %%
result_df.shape
# Out:
# (39654, 10)

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39654 entries, 0 to 39653
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        39654 non-null  int64
#  1   date        39654 non-null  object
#  2   home_team   39654 non-null  object
#  3   away_team   39654 non-null  object
#  4   home_score  39654 non-null  int64
#  5   away_score  39654 non-null  int64
#  6   tournament  39654 non-null  object
#  7   city        39654 non-null  object
#  8   country     39654 non-null  object
#  9   neutral     39654 non-null  bool
# dtypes: bool(1), int64(3), object(6)
# memory usage: 2.8+ MB

# %%
result_df.describe()
# Out:
#                year    home_score    away_score
# count  39654.000000  39654.000000  39654.000000
# mean    1989.267489      1.746280      1.186362
# std       23.995383      1.747455      1.400080
# min     1872.000000      0.000000      0.000000
# 25%     1977.000000      1.000000      0.000000
# 50%     1996.000000      1.000000      1.000000
# 75%     2008.000000      2.000000      2.000000
# max     2018.000000     31.000000     21.000000

# %%
len(result_df)
# Out:
# 39654

# %%
result_df.tail()
# Out:
#        year       date    home_team   away_team  home_score  away_score  \
# 39649  2018  26/7/2018  Switzerland  Costa Rica           0           0
# 39650  2018  27/7/2018        Japan      Poland           0           0
# 39651  2018  28/7/2018      Senegal    Colombia           0           0
# 39652  2018  29/7/2018       Panama     Tunisia           0           0
# 39653  2018  30/7/2018      England     Belgium           0           0
#
#       tournament  city country  neutral
# 39649       FIFA  FIFA    FIFA     True
# 39650       FIFA  FIFA    FIFA     True
# 39651       FIFA  FIFA    FIFA     True
# 39652       FIFA  FIFA    FIFA     True
# 39653       FIFA  FIFA    FIFA     True

# %%
# Empty Array with Winners
winner = []

# Fill array with winners
for i in range(len(result_df)):
    if result_df['home_score'][i] > result_df['away_score'][i]:
        winner.append(result_df['home_team'][i])
    elif result_df['home_score'][i] < result_df['away_score'][i]:
        winner.append(result_df['away_team'][i])
    else:
        winner.append('Tie')

# %%
len(winner)
# Out:
# 39654

# %%
# Add new column within array
result_df['winner'] = winner

# %%
result_df.head()
# Out:
#    year        date home_team away_team  home_score  away_score tournament  \
# 0  1872  1872-11-30  Scotland   England           0           0   Friendly
# 1  1873  1873-03-08   England  Scotland           4           2   Friendly
# 2  1874  1874-03-07  Scotland   England           2           1   Friendly
# 3  1875  1875-03-06   England  Scotland           2           2   Friendly
# 4  1876  1876-03-04  Scotland   England           3           0   Friendly
#
#       city   country  neutral    winner
# 0  Glasgow  Scotland    False       Tie
# 1   London   England    False   England
# 2  Glasgow  Scotland    False  Scotland
# 3   London   England    False       Tie
# 4  Glasgow  Scotland    False  Scotland

# %%
result_df['goal_difference'] = np.absolute(result_df['home_score'] - result_df['away_score'])

# %%
result_df.head(9)
# Out:
#    year        date home_team away_team  home_score  away_score tournament  \
# 0  1872  1872-11-30  Scotland   England           0           0   Friendly
# 1  1873  1873-03-08   England  Scotland           4           2   Friendly
# 2  1874  1874-03-07  Scotland   England           2           1   Friendly
# 3  1875  1875-03-06   England  Scotland           2           2   Friendly
# 4  1876  1876-03-04  Scotland   England           3           0   Friendly
# 5  1876  1876-03-25  Scotland     Wales           4           0   Friendly
# 6  1877  1877-03-03   England  Scotland           1           3   Friendly
# 7  1877  1877-03-05     Wales  Scotland           0           2   Friendly
# 8  1878  1878-03-02  Scotland   England           7           2   Friendly
#
#       city   country  neutral    winner  goal_difference
# 0  Glasgow  Scotland    False       Tie                0
# 1   London   England    False   England                2
# ...

# %%
argentina_df = result_df[(result_df['home_team'] == 'Argentina') | (result_df['away_team'] == 'Argentina')]

# %%
argentina_df.shape
# Out:
# (956, 12)

# %%
argentina_df.head()
# Out:
#      year        date  home_team  away_team  home_score  away_score  \
# 144  1902   20/7/1902    Uruguay  Argentina           0           6
# 152  1903   13/9/1903  Argentina    Uruguay           2           3
# 173  1905   15/8/1905  Argentina    Uruguay           0           0
# 184  1906   15/8/1906    Uruguay  Argentina           0           2
# 186  1906  21/10/1906  Argentina    Uruguay           2           1
#
#       tournament          city    country  neutral     winner  goal_difference
# 144     Friendly    Montevideo    Uruguay    False  Argentina                6
# 152     Friendly  Buenos Aires  Argentina    False    Uruguay                1
# 173  Copa Lipton  Buenos Aires  Argentina    False        Tie                0
# 184  Copa Lipton    Montevideo    Uruguay    False  Argentina                2
# 186  Copa Newton  Buenos Aires  Argentina    False  Argentina                1

# %%
argentina_year = argentina_df[argentina_df['year']== 1930]

# %%
argentina_year.shape
# Out:
# (7, 12)

# %%
argentina_year.head(7)
# Out:
#       year       date  home_team   away_team  home_score  away_score  \
# 1259  1930  25/5/1930  Argentina     Uruguay           1           1
# 1281  1930  15/7/1930  Argentina      France           1           0
# 1287  1930  19/7/1930  Argentina      Mexico           6           3
# 1292  1930  22/7/1930  Argentina       Chile           3           1
# 1294  1930  26/7/1930  Argentina         USA           6           1
# 1296  1930  30/7/1930    Uruguay   Argentina           4           2
# 1298  1930   3/8/1930  Argentina  Yugoslavia           3           1
#
#           tournament          city    country  neutral     winner  \
# 1259     Copa Newton  Buenos Aires  Argentina    False        Tie
# 1281  FIFA World Cup    Montevideo    Uruguay     True  Argentina
# 1287  FIFA World Cup    Montevideo    Uruguay     True  Argentina
# 1292  FIFA World Cup    Montevideo    Uruguay     True  Argentina
# 1294  FIFA World Cup    Montevideo    Uruguay     True  Argentina
# ...

# %%
argentina_year.count()
# Out:
# year               7
# date               7
# home_team          7
# away_team          7
# home_score         7
# away_score         7
# tournament         7
# city               7
# country            7
# neutral            7
# winner             7
# goal_difference    7
# dtype: int64

# %%
# Chart auxiliar

winrate = []

for row in argentina_year['winner']:
    if row != 'Argentina':
        winrate.append('Lost')
    elif row == 'Tie':
        winrate.append('Tie')
    else:
        winrate.append('Win')

# %%
winrate
# Out:
# ['Lost', 'Win', 'Win', 'Win', 'Win', 'Lost', 'Win']

# %%
winrate_df = pd.DataFrame(data=winrate, columns=['Result'])

# %%
winrate_df.head(7)
# Out:
#   Result
# 0   Lost
# 1    Win
# 2    Win
# 3    Win
# 4    Win
# 5   Lost
# 6    Win

# %%
wc_teams = ['Australia', ' Iran', 'Japan', 'Korea Republic', 
            'Saudi Arabia', 'Egypt', 'Morocco', 'Nigeria', 
            'Senegal', 'Tunisia', 'Costa Rica', 'Mexico', 
            'Panama', 'Argentina', 'Brazil', 'Colombia', 
            'Peru', 'Uruguay', 'Belgium', 'Croatia', 
            'Denmark', 'England', 'France', 'Germany', 
            'Iceland', 'Poland', 'Portugal', 'Russia', 
            'Serbia', 'Spain', 'Sweden', 'Switzerland']

# %%
df_teams_home = result_df[result_df['home_team'].isin(wc_teams)]
df_teams_away = result_df[result_df['away_team'].isin(wc_teams)]

# %%
df_teams_home.head()
# Out:
#     year        date home_team away_team  home_score  away_score tournament  \
# 1   1873  1873-03-08   England  Scotland           4           2   Friendly
# 3   1875  1875-03-06   England  Scotland           2           2   Friendly
# 6   1877  1877-03-03   England  Scotland           1           3   Friendly
# 10  1879  1879-01-18   England     Wales           2           1   Friendly
# 11  1879  1879-04-05   England  Scotland           5           4   Friendly
#
#       city  country  neutral    winner  goal_difference
# 1   London  England    False   England                2
# 3   London  England    False       Tie                0
# 6   London  England    False  Scotland                2
# 10  London  England    False   England                1
# 11  London  England    False   England                1

# %%
df_teams_home.shape
# Out:
# (10638, 12)

# %%
df_teams_away.head()
# Out:
#     year        date home_team away_team  home_score  away_score tournament  \
# 0   1872  1872-11-30  Scotland   England           0           0   Friendly
# 2   1874  1874-03-07  Scotland   England           2           1   Friendly
# 4   1876  1876-03-04  Scotland   England           3           0   Friendly
# 8   1878  1878-03-02  Scotland   England           7           2   Friendly
# 13  1880  1880-03-13  Scotland   England           5           4   Friendly
#
#        city   country  neutral    winner  goal_difference
# 0   Glasgow  Scotland    False       Tie                0
# 2   Glasgow  Scotland    False  Scotland                1
# 4   Glasgow  Scotland    False  Scotland                3
# 8   Glasgow  Scotland    False  Scotland                5
# 13  Glasgow  Scotland    False  Scotland                1

# %%
df_teams_away.shape
# Out:
# (10124, 12)
